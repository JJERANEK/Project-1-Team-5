# %% [markdown]
# ## What does the FHFA HPI represent?
# The FHFA HPI is a broad measure of the movement of single-family house prices. The FHFA HPI is a weighted, repeat-sales index, meaning that it measures average price changes in repeat sales or refinancings on the same properties. This information is obtained by reviewing repeat mortgage transactions on single-family properties whose mortgages have been purchased or securitized by Fannie Mae or Freddie Mac since January 1975.
#
# The FHFA HPI serves as a timely, accurate indicator of house price trends at various geographic levels. Because of the breadth of the sample, it provides more information than is available in other house price indexes. It also provides housing economists with an improved analytical tool that is useful for estimating changes in the rates of mortgage defaults, prepayments and housing affordability in specific geographic areas.

# %%
import pandas as pd 
import csv
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## HPI for State of Minnesota

# %%
csvpath = "Datasets/HPI_AT_BDL_state.csv"

house_price_index = pd.read_csv(csvpath)
house_price_index.head(10)
# Out:
#   HPI for states (All-Transactions Index)\nExperimental Indexes Showing Cumulative (Nominal) Annual Appreciation  \
# 0                                                NaN
# 1  * These annual state indexes should be conside...
# 2  ** For tracking and feedback purposes, please ...
# 3                      Last updated: March 24, 2022.
# 4                     Not Seasonally Adjusted (NSA)
# 5                                              State
# 6                                            Alabama
# 7                                            Alabama
# 8                                            Alabama
# 9                                            Alabama
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3         Unnamed: 4 Unnamed: 5  \
# 0           NaN        NaN        NaN                NaN        NaN
# 1           NaN        NaN        NaN                NaN        NaN
# 2           NaN        NaN        NaN                NaN        NaN
# 3           NaN        NaN        NaN                NaN        NaN
# 4           NaN        NaN        NaN                NaN        NaN
# 5  Abbreviation       FIPS       Year  Annual Change (%)        HPI
# 6            AL         01       1975                  .     100.00
# 7            AL         01       1976               6.70     106.70
# 8            AL         01       1977              10.00     117.37
# 9            AL         01       1978               8.38     127.21
#
#            Unnamed: 6          Unnamed: 7  Unnamed: 8
# 0                 NaN                 NaN         NaN
# 1                 NaN                 NaN         NaN
# 2                 NaN                 NaN         NaN
# 3                 NaN                 NaN         NaN
# 4                 NaN                 NaN         NaN
# 5  HPI with 1990 base  HPI with 2000 base         NaN
# 6               49.74               36.16         NaN
# 7               53.08               38.58         NaN
# 8               58.39               42.44         NaN
# 9               63.28               46.00         NaN

# %%
house_price_index_nohead = house_price_index.drop([0, 1, 2, 3, 4])
house_price_index_nohead.head()
# Out:
#   HPI for states (All-Transactions Index)\nExperimental Indexes Showing Cumulative (Nominal) Annual Appreciation  \
# 5                                              State
# 6                                            Alabama
# 7                                            Alabama
# 8                                            Alabama
# 9                                            Alabama
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3         Unnamed: 4 Unnamed: 5  \
# 5  Abbreviation       FIPS       Year  Annual Change (%)        HPI
# 6            AL         01       1975                  .     100.00
# 7            AL         01       1976               6.70     106.70
# 8            AL         01       1977              10.00     117.37
# 9            AL         01       1978               8.38     127.21
#
#            Unnamed: 6          Unnamed: 7  Unnamed: 8
# 5  HPI with 1990 base  HPI with 2000 base         NaN
# 6               49.74               36.16         NaN
# 7               53.08               38.58         NaN
# 8               58.39               42.44         NaN
# 9               63.28               46.00         NaN

# %%
house_price_index_nohead.columns
# Out:
# Index(['HPI for states (All-Transactions Index)\nExperimental Indexes Showing Cumulative (Nominal) Annual Appreciation',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
house_price_index_nohead.rename(columns=house_price_index_nohead.iloc[0], inplace=True)
house_price_index_nohead.head()
# Out:
#      State  Abbreviation  FIPS  Year  Annual Change (%)     HPI  \
# 5    State  Abbreviation  FIPS  Year  Annual Change (%)     HPI
# 6  Alabama            AL    01  1975                  .  100.00
# 7  Alabama            AL    01  1976               6.70  106.70
# 8  Alabama            AL    01  1977              10.00  117.37
# 9  Alabama            AL    01  1978               8.38  127.21
#
#    HPI with 1990 base  HPI with 2000 base  NaN
# 5  HPI with 1990 base  HPI with 2000 base  NaN
# 6               49.74               36.16  NaN
# 7               53.08               38.58  NaN
# 8               58.39               42.44  NaN
# 9               63.28               46.00  NaN

# %%
minnesota_hpi = house_price_index_nohead.loc[house_price_index_nohead["State"] == "Minnesota"]
minnesota_hpi.head()
# Out:
#           State Abbreviation FIPS  Year Annual Change (%)     HPI  \
# 1087  Minnesota           MN   27  1975                 .  100.00
# 1088  Minnesota           MN   27  1976              8.82  108.82
# 1089  Minnesota           MN   27  1977             11.47  121.31
# 1090  Minnesota           MN   27  1978             17.49  142.53
# 1091  Minnesota           MN   27  1979             14.50  163.20
#
#      HPI with 1990 base HPI with 2000 base  NaN
# 1087              41.95              25.90  NaN
# 1088              45.65              28.18  NaN
# 1089              50.89              31.41  NaN
# 1090              59.79              36.91  NaN
# 1091              68.46              42.26  NaN

# %%
minnesota_hpi_10_years = minnesota_hpi[(minnesota_hpi["Year"] > "2010") & (minnesota_hpi["Year"] <= "2021")]
minnesota_hpi_10_years
# Out:
#           State Abbreviation FIPS  Year Annual Change (%)     HPI  \
# 1123  Minnesota           MN   27  2011             -5.34  452.74
# 1124  Minnesota           MN   27  2012             -1.48  446.03
# 1125  Minnesota           MN   27  2013              3.99  463.85
# 1126  Minnesota           MN   27  2014              5.71  490.34
# 1127  Minnesota           MN   27  2015              3.31  506.56
# 1128  Minnesota           MN   27  2016              4.62  529.96
# 1129  Minnesota           MN   27  2017              5.83  560.85
# 1130  Minnesota           MN   27  2018              5.66  592.58
# 1131  Minnesota           MN   27  2019              4.05  616.58
# 1132  Minnesota           MN   27  2020              2.55  632.32
# 1133  Minnesota           MN   27  2021              9.55  692.73
#
#      HPI with 1990 base HPI with 2000 base  NaN
# 1123             189.92             117.24  NaN
# 1124             187.10             115.51  NaN
# 1125             194.58             120.12  NaN
# 1126             205.69             126.98  NaN
# 1127             212.50             131.18  NaN
# 1128             222.31             137.24  NaN
# 1129             235.27             145.24  NaN
# 1130             248.58             153.46  NaN
# 1131             258.64             159.67  NaN
# 1132             265.25             163.75  NaN
# 1133             290.59             179.40  NaN

# %%
minnesota_hpi_10_years["HPI"] = minnesota_hpi_10_years["HPI"].map(float)
# Out:
# c:\Users\Jordan\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x_axis = minnesota_hpi_10_years["Year"]
y_axis = minnesota_hpi_10_years["HPI"]
plt.plot(x_axis, y_axis)
plt.show()

# %% [markdown]
# ## HPI for Minneapolis/St. Paul

# %%
csvpath2 = "Datasets/HPI_AT_metro.csv"

msp_hpi_start = pd.read_csv(csvpath2, header=None)
headers = ["City", "ID", "Year", "Qtr", "HPI", "Annual Change %"]
msp_hpi_start.columns = headers
msp_hpi_start.head(10)
# Out:
#           City     ID  Year  Qtr HPI Annual Change %
# 0  Abilene, TX  10180  1975    1   -               -
# 1  Abilene, TX  10180  1975    2   -               -
# 2  Abilene, TX  10180  1975    3   -               -
# 3  Abilene, TX  10180  1975    4   -               -
# 4  Abilene, TX  10180  1976    1   -               -
# 5  Abilene, TX  10180  1976    2   -               -
# 6  Abilene, TX  10180  1976    3   -               -
# 7  Abilene, TX  10180  1976    4   -               -
# 8  Abilene, TX  10180  1977    1   -               -
# 9  Abilene, TX  10180  1977    2   -               -

# %%
msp_hpi_all = msp_hpi_start.loc[msp_hpi_start["City"] == "Minneapolis-St. Paul-Bloomington, MN-WI"]
msp_hpi_all.head()
# Out:
#                                           City     ID  Year  Qtr HPI  \
# 45410  Minneapolis-St. Paul-Bloomington, MN-WI  33460  1975    1   -
# 45411  Minneapolis-St. Paul-Bloomington, MN-WI  33460  1975    2   -
# 45412  Minneapolis-St. Paul-Bloomington, MN-WI  33460  1975    3   -
# 45413  Minneapolis-St. Paul-Bloomington, MN-WI  33460  1975    4   -
# 45414  Minneapolis-St. Paul-Bloomington, MN-WI  33460  1976    1   -
#
#       Annual Change %
# 45410               -
# 45411               -
# 45412               -
# 45413               -
# 45414               -

# %%
msp_hpi_all["Year"] = msp_hpi_all["Year"].map(str)
msp_hpi_all.dtypes
# Out:
# c:\Users\Jordan\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# City               object
# ID                  int64
# Year               object
# Qtr                 int64
# HPI                object
# Annual Change %    object
# dtype: object

# %%
msp_hpi_10_years = msp_hpi_all[(msp_hpi_all["Year"] > "2010") & (msp_hpi_all["Year"] <= "2021")]
msp_hpi_10_years.head()
# Out:
#                                           City     ID  Year  Qtr     HPI  \
# 45554  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2011    1  177.56
# 45555  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2011    2   172.4
# 45556  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2011    3  174.51
# 45557  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2011    4  176.04
# 45558  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2012    1  172.73
#
#       Annual Change %
# 45554           -0.39
# 45555           -0.39
# 45556           -0.37
# 45557           -0.36
# 45558           -0.36

# %%
msp_hpi_10_qtr_4 = msp_hpi_10_years.loc[msp_hpi_10_years["Qtr"] == 4]
msp_hpi_10_qtr_4
# Out:
#                                           City     ID  Year  Qtr     HPI  \
# 45557  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2011    4  176.04
# 45561  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2012    4  177.25
# 45565  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2013    4  188.32
# 45569  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2014    4  198.03
# 45573  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2015    4   206.9
# 45577  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2016    4  217.58
# 45581  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2017    4  230.87
# 45585  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2018    4  243.26
# 45589  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2019    4  254.96
# 45593  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2020    4  269.77
# 45597  Minneapolis-St. Paul-Bloomington, MN-WI  33460  2021    4  306.99
#
#       Annual Change %
# 45557           -0.36
# 45561           -0.37
# 45565           -0.44
# 45569           -0.45
# 45573           -0.48
# 45577           -0.47
# 45581           -0.52
# 45585           -0.54
# 45589           -0.53
# 45593           -0.55
# 45597           -0.67

# %%
msp_hpi_10_qtr_4["HPI"] = msp_hpi_10_qtr_4["HPI"].map(float)
# Out:
# c:\Users\Jordan\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Chart
x_axis = msp_hpi_10_qtr_4["Year"]
y_axis = msp_hpi_10_qtr_4["HPI"]

plt.plot(x_axis, y_axis)
plt.show()

# %% [markdown]
# ## HPI for Nonmetro Minnesota

# %%
csvpath3 = "Datasets/HPI_AT_nonmetro.csv"

greatermn_hpi_start = pd.read_csv(csvpath3, header=None)
greatermn_hpi_start.rename(columns=greatermn_hpi_start.iloc[2], inplace=True)
greatermn_hpi_start.head(10)
# Out:
#                                                State  Year  Quarter   Index  \
# 0  FHFA HPI® State Indexes for Houses \nnot in Me...   NaN      NaN     NaN
# 1                                                NaN   NaN      NaN     NaN
# 2                                              State  Year  Quarter   Index
# 3                                                 AK  1995        1  100.00
# 4                                                 AK  1995        2  104.06
# 5                                                 AK  1995        3  102.53
# 6                                                 AK  1995        4  103.94
# 7                                                 AK  1996        1  107.87
# 8                                                 AK  1996        2  108.00
# 9                                                 AK  1996        3  109.33
#
#    Standard Error
# 0             NaN
# 1             NaN
# 2  Standard Error
# 3         ( 0.00)
# 4         ( 1.73)
# 5         ( 1.43)
# 6         ( 1.58)
# 7         ( 1.52)
# 8         ( 1.53)
# 9         ( 1.64)

# %%
greatermn_hpi_all = greatermn_hpi_start.loc[greatermn_hpi_start["State"] == "MN"]
greatermn_hpi_all.head()
# Out:
#      State  Year Quarter   Index Standard Error
# 2313    MN  1995       1  100.00        ( 0.00)
# 2314    MN  1995       2  101.83        ( 0.80)
# 2315    MN  1995       3  103.94        ( 0.74)
# 2316    MN  1995       4  106.22        ( 0.75)
# 2317    MN  1996       1  107.70        ( 0.74)

# %%
greatermn_hpi_10_years = greatermn_hpi_all[(greatermn_hpi_all["Year"] > "2010") & (greatermn_hpi_all["Year"] <= "2021")]
greatermn_hpi_10_years.dtypes
# Out:
# State             object
# Year              object
# Quarter           object
# Index             object
# Standard Error    object
# dtype: object

# %%
greatermn_hpi_10_qtr_4 = greatermn_hpi_10_years.loc[(greatermn_hpi_10_years["Quarter"] == "4")]
greatermn_hpi_10_qtr_4
# Out:
#      State  Year Quarter   Index Standard Error
# 2380    MN  2011       4  189.34        ( 1.24)
# 2384    MN  2012       4  187.70        ( 1.24)
# 2388    MN  2013       4  188.74        ( 1.34)
# 2392    MN  2014       4  194.78        ( 1.38)
# 2396    MN  2015       4  201.47        ( 1.43)
# 2400    MN  2016       4  210.03        ( 1.45)
# 2404    MN  2017       4  219.48        ( 1.53)
# 2408    MN  2018       4  227.45        ( 1.55)
# 2412    MN  2019       4  239.73        ( 1.59)
# 2416    MN  2020       4  253.09        ( 1.66)
# 2420    MN  2021       4  294.52        ( 2.02)

# %%
greatermn_hpi_10_qtr_4["Index"] = greatermn_hpi_10_qtr_4["Index"].map(float)
# Out:
# c:\Users\Jordan\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Chart
x_axis = greatermn_hpi_10_qtr_4["Year"]
y_axis = greatermn_hpi_10_qtr_4["Index"]

plt.plot(x_axis, y_axis)
plt.show()

# %%
# Chart Together
#all_x_axis = minnesota_hpi_10_years["Year"]
#all_y_axis = minnesota_hpi_10_years["HPI"]
#all_mn = plt.plot(all_x_axis, all_y_axis, color="blue", label="Total Minnesota")

msp_x_axis = msp_hpi_10_qtr_4["Year"]
msp_y_axis = msp_hpi_10_qtr_4["HPI"]
msp_line = plt.plot(msp_x_axis, msp_y_axis, color="red", label="Minneapolis/St. Paul")

greater_x_axis = greatermn_hpi_10_qtr_4["Year"]
greater_y_axis = greatermn_hpi_10_qtr_4["Index"]
greater_line = plt.plot(greater_x_axis, greater_y_axis, color="green", label="Greater Minnesota")

plt.legend()

plt.show()
