# %% [markdown]
# Minnesota

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
loading_cost_of_living = "Resources/mn_cost_of_living_2021.csv"
loading_weekly_wages = "Resources/mn_weekly_wages_edr2021.csv"

# %%
#Read file and save as DataFrame
cost_of_living = pd.read_csv(loading_cost_of_living)
weekly_wages = pd.read_csv(loading_weekly_wages)

# %% [markdown]
# Created 1 merged document if needed.
# ****Still need to delete extra columns******

# %%
#Copy the cost of livingRename column headings to match for merge
cost_of_living2 = cost_of_living.copy()

#Rename the "Area" column to "areaname" to match other csv file
cost_of_living2 = cost_of_living2.rename(columns={"Area":"areaname"})
cost_of_living2.head()
# Out:
#                            areaname  Family Size  Number of Adults  \
# 0  Aitkin County                               1                 1
# 1  Aitkin County                               1                 1
# 2  Anoka County                                1                 1
# 3  Anoka County                                1                 1
# 4  Becker County                               1                 1
#
#    Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 0                1.0                   0           51+        30874
# 1                1.0                   0         19-50        30471
# 2                1.0                   0         19-50        36938
# 3                1.0                   0           51+        37268
# 4                1.0                   0         19-50        28659
#
#    Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 0        14.84           0   341          191      570        863    249
# 1        14.65           0   353          152      570        863    253
# 2        17.76           0   354          161     1066        680    389
# 3        17.92           0   342          199     1066        680    385
# 4        13.78           0   353          152      592        722    259
#
#    Taxes
# 0    359
# 1    348
# 2    428
# 3    434
# 4    310

# %%
# Create one data set (If needed). Used inner to only show the EDRs
merged_data_df = pd.merge(cost_of_living2, weekly_wages, on="areaname", how="inner")
merged_data_df
# Out:
#                                areaname  Family Size  Number of Adults  \
# 0      EDR  1 - Northwest                          1                 1
# 1      EDR  1 - Northwest                          1                 1
# 2      EDR  1 - Northwest                          1                 1
# 3      EDR  1 - Northwest                          1                 1
# 4      EDR  1 - Northwest                          1                 1
# ...                                 ...          ...               ...
# 17443  EDR 11 - 7 County Twin Cities               6                 2
# 17444  EDR 11 - 7 County Twin Cities               6                 2
# 17445  EDR 11 - 7 County Twin Cities               6                 2
# 17446  EDR 11 - 7 County Twin Cities               6                 2
# 17447  EDR 11 - 7 County Twin Cities               6                 2
#
#        Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 0                    1.0                   0         19-50        27960
# 1                    1.0                   0         19-50        27960
# 2                    1.0                   0         19-50        27960
# 3                    1.0                   0         19-50        27960
# 4                    1.0                   0         19-50        27960
# ...                  ...                 ...           ...          ...
# 17443                1.5                   4         19-50        96036
# 17444                1.5                   4         19-50        96036
# 17445                1.5                   4         19-50        96036
# 17446                1.5                   4         19-50        96036
# 17447                1.5                   4         19-50        96036
#
#        Hourly Wage  Child Care  Food  ...  deaths_estabs2  deaths_estabs3  \
# 0            13.44           0   357  ...          999999          999999
# 1            13.44           0   357  ...          999999          999999
# 2            13.44           0   357  ...          999999          999999
# 3            13.44           0   357  ...          999999          999999
# 4            13.44           0   357  ...          999999          999999
# ...            ...         ...   ...  ...             ...             ...
# 17443        30.78        1264  1603  ...          999999          999999
# 17444        30.78        1264  1603  ...          999999          999999
# 17445        30.78        1264  1603  ...          999999          999999
# 17446        30.78        1264  1603  ...          999999          999999
# 17447        30.78        1264  1603  ...          999999          999999
#
#        deaths_estabs4  deaths_estabsYear  deaths_employ1  deaths_employ2  \
# 0              999999             999999             212          999999
# 1              999999             999999               7          999999
# 2              999999             999999             205          999999
# 3              999999             999999          999999          999999
# 4              999999             999999          999999          999999
# ...               ...                ...             ...             ...
# 17443          999999             999999          999999          999999
# 17444          999999             999999          999999          999999
# 17445          999999             999999          999999          999999
# 17446          999999             999999              28          999999
# 17447          999999             999999              28          999999
#
#       deaths_employ3  deaths_employ4  deaths_employYear Unnamed: 81
# 0             999999          999999             999999         NaN
# 1             999999          999999             999999         NaN
# 2             999999          999999             999999         NaN
# 3             999999          999999             999999         NaN
# 4             999999          999999             999999         NaN
# ...              ...             ...                ...         ...
# 17443         999999          999999             999999         NaN
# 17444         999999          999999             999999         NaN
# 17445         999999          999999             999999         NaN
# 17446         999999          999999             999999         NaN
# 17447         999999          999999             999999         NaN
#
# [17448 rows x 96 columns]

# %%
#Checking the types of each column
cost_of_living.dtypes
# Out:
# Area                   object
# Family Size             int64
# Number of Adults        int64
# Number of Workers     float64
# Number of Children      int64
# Age of Adults          object
# Yearly Cost             int64
# Hourly Wage           float64
# Child Care              int64
# Food                    int64
# Health Care             int64
# Housing                 int64
# Transport               int64
# Other                   int64
# Taxes                   int64
# dtype: object

# %%
#In new Cost of Living df only keep the area's that are EDR Regions.
cost_of_living_EDR = cost_of_living[cost_of_living["Area"].str.contains("EDR")==True]
cost_of_living_EDR
# Out:
#                                   Area  Family Size  Number of Adults  \
# 44    EDR  1 - Northwest                          1                 1
# 45    EDR  1 - Northwest                          1                 1
# 46    EDR  2 - Headwaters                         1                 1
# 47    EDR  2 - Headwaters                         1                 1
# 48    EDR  3 - Arrowhead                          1                 1
# ...                                ...          ...               ...
# 2347  EDR 10 - Southeast                          6                 2
# 2348  EDR 10 - Southeast                          6                 2
# 2349  EDR 11 - 7 County Twin Cities               6                 2
# 2350  EDR 11 - 7 County Twin Cities               6                 2
# 2351  EDR 11 - 7 County Twin Cities               6                 2
#
#       Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 44                  1.0                   0         19-50        27960
# 45                  1.0                   0           51+        28332
# 46                  1.0                   0         19-50        28704
# 47                  1.0                   0           51+        29064
# 48                  1.0                   0           51+        29628
# ...                 ...                 ...           ...          ...
# 2347                2.0                   4         19-50        81720
# 2348                1.5                   4         19-50        71784
# 2349                1.0                   4         19-50        74544
# 2350                2.0                   4         19-50       117192
# 2351                1.5                   4         19-50        96036
#
#       Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 44          13.44           0   357          152      622        635    268
# 45          13.62           0   345          191      622        635    265
# 46          13.80           0   354          152      598        716    260
# 47          13.97           0   342          191      598        716    257
# 48          14.24           0   341          191      665        673    275
# ...           ...         ...   ...          ...      ...        ...    ...
# 2347        19.64        1236  1558          570     1247        873    768
# 2348        23.01         618  1558          570     1247        873    768
# 2349        35.84           0  1603          607     1894        822    958
# 2350        28.17        2528  1603          607     1894        822    958
# 2351        30.78        1264  1603          607     1894        822    958
#
#       Taxes
# 44      296
# 45      303
# 46      312
# 47      318
# 48      324
# ...     ...
# 2347    558
# 2348    348
# 2349    328
# 2350   1354
# 2351    855
#
# [312 rows x 15 columns]

# %% [markdown]
# Created data sets for each EDR

# %%
#Combine data for each EDR into 1 data set - EDR 1 - Northwest
EDR_1_NW = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("Northwest") == True]
EDR_1_NW.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 44   EDR  1 - Northwest                          1                 1
# 45   EDR  1 - Northwest                          1                 1
# 368  EDR  1 - Northwest                          2                 2
# 369  EDR  1 - Northwest                          2                 2
# 370  EDR  1 - Northwest                          2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 44                 1.0                   0         19-50        27960
# 45                 1.0                   0           51+        28332
# 368                2.0                   0         19-50        38964
# 369                1.5                   0           51+        39720
# 370                1.5                   0         19-50        38964
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 44         13.44           0   357          152      622        635    268
# 45         13.62           0   345          191      622        635    265
# 368         9.37           0   654          496      631        686    352
# 369        12.73           0   632          573      631        686    346
# 370        12.49           0   654          496      631        686    352
#
#      Taxes
# 44     296
# 45     303
# 368    428
# 369    442
# 370    428

# %%
#Combine data for each EDR into 1 data set - EDR 2 - Headwaters
EDR_2_hw = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("Headwaters") == True]
EDR_2_hw.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 46   EDR  2 - Headwaters                         1                 1
# 47   EDR  2 - Headwaters                         1                 1
# 375  EDR  2 - Headwaters                         2                 2
# 376  EDR  2 - Headwaters                         2                 2
# 377  EDR  2 - Headwaters                         2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 46                 1.0                   0         19-50        28704
# 47                 1.0                   0           51+        29064
# 375                1.0                   0         19-50        38916
# 376                1.5                   0         19-50        39804
# 377                1.5                   0           51+        40572
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 46         13.80           0   354          152      598        716    260
# 47         13.97           0   342          191      598        716    257
# 375        18.71           0   649          496      606        778    343
# 376        12.76           0   649          496      606        778    343
# 377        13.00           0   627          573      606        778    338
#
#      Taxes
# 46     312
# 47     318
# 375    371
# 376    445
# 377    459

# %%
#Combine data for each EDR into 1 data set - EDR 3 - Arrowhead
EDR_3_aw = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("Arrowhead") == True]
EDR_3_aw.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 48   EDR  3 - Arrowhead                          1                 1
# 49   EDR  3 - Arrowhead                          1                 1
# 382  EDR  3 - Arrowhead                          2                 2
# 383  EDR  3 - Arrowhead                          2                 1
# 384  EDR  3 - Arrowhead                          2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 48                 1.0                   0           51+        29628
# 49                 1.0                   0         19-50        29268
# 382                2.0                   0           51+        40980
# 383                1.0                   1         19-50        48072
# 384                1.0                   0           51+        40044
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 48         14.24           0   341          191      665        673    275
# 49         14.07           0   353          152      665        673    279
# 382         9.85           0   626          573      668        730    354
# 383        23.11         704   523          482      877        678    383
# 384        19.25           0   626          573      668        730    354
#
#      Taxes
# 48     324
# 49     317
# 382    464
# 383    359
# 384    386

# %%
#Combine data for each EDR into 1 data set - EDR 4 - West Central
EDR_4_WC = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("West Central") == True]
EDR_4_WC.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 50   EDR  4 - West Central                       1                 1
# 51   EDR  4 - West Central                       1                 1
# 389  EDR  4 - West Central                       2                 2
# 390  EDR  4 - West Central                       2                 2
# 391  EDR  4 - West Central                       2                 1
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 50                 1.0                   0           51+        28896
# 51                 1.0                   0         19-50        28524
# 389                2.0                   0         19-50        39600
# 390                1.5                   0         19-50        39600
# 391                1.0                   1         19-50        43656
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 50         13.89           0   342          191      621        677    264
# 51         13.71           0   354          152      621        677    267
# 389         9.52           0   649          496      631        734    351
# 390        12.69           0   649          496      631        734    351
# 391        20.99         526   524          482      799        681    362
#
#      Taxes
# 50     313
# 51     306
# 389    439
# 390    439
# 391    264

# %%
#Combine data for each EDR into 1 data set - EDR 5 - North Central
EDR_5_NC = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("North Central") == True]
EDR_5_NC.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 52   EDR  5 - North Central                      1                 1
# 53   EDR  5 - North Central                      1                 1
# 396  EDR  5 - North Central                      2                 2
# 397  EDR  5 - North Central                      2                 2
# 398  EDR  5 - North Central                      2                 1
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 52                 1.0                   0         19-50        29244
# 53                 1.0                   0           51+        29604
# 396                1.0                   0           51+        40284
# 397                2.0                   0           51+        41184
# 398                1.0                   1         19-50        45060
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 52         14.06           0   351          152      590        762    258
# 53         14.23           0   339          191      590        762    254
# 396        19.37           0   622          573      601        830    335
# 397         9.90           0   622          573      601        830    335
# 398        21.66         550   519          482      780        768    356
#
#      Taxes
# 52     324
# 53     331
# 396    396
# 397    471
# 398    300

# %%
#Combine data for each EDR into 1 data set - EDR 6E - SouthWest Central
EDR_6E_SWC = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("Southwest Central") == True]
EDR_6E_SWC.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 54   EDR  6E- Southwest Central                  1                 1
# 55   EDR  6E- Southwest Central                  1                 1
# 403  EDR  6E- Southwest Central                  2                 1
# 404  EDR  6E- Southwest Central                  2                 2
# 405  EDR  6E- Southwest Central                  2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 54                 1.0                   0           51+        28764
# 55                 1.0                   0         19-50        28380
# 403                1.0                   1         19-50        44016
# 404                1.0                   0         19-50        38544
# 405                2.0                   0           51+        40164
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 54         13.83           0   342          191      597        696    257
# 55         13.64           0   354          152      597        696    260
# 403        21.16         561   524          482      769        701    354
# 404        18.53           0   649          496      604        755    343
# 405         9.65           0   627          573      604        755    337
#
#      Taxes
# 54     314
# 55     306
# 403    277
# 404    365
# 405    451

# %%
#Combine data for each EDR into 1 data set - EDR 6W - Upper MN Valley
EDR_6W_umnv = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("Upper Minnesota Valley") == True]
EDR_6W_umnv.head()
# Out:
#                                 Area  Family Size  Number of Adults  \
# 56   EDR  6W- Upper Minnesota Valley            1                 1
# 57   EDR  6W- Upper Minnesota Valley            1                 1
# 410  EDR  6W- Upper Minnesota Valley            2                 2
# 411  EDR  6W- Upper Minnesota Valley            2                 2
# 412  EDR  6W- Upper Minnesota Valley            2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 56                 1.0                   0           51+        27936
# 57                 1.0                   0         19-50        27588
# 410                2.0                   0           51+        39444
# 411                2.0                   0         19-50        38664
# 412                1.0                   0           51+        38580
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 56         13.43           0   350          191      571        664    252
# 57         13.26           0   362          152      571        664    256
# 410         9.48           0   642          573      579        719    334
# 411         9.29           0   664          496      579        719    340
# 412        18.55           0   642          573      579        719    334
#
#      Taxes
# 56     300
# 57     294
# 410    440
# 411    424
# 412    368

# %%
#Combine data for each EDR into 1 data set - EDR 7E - East Central
EDR_7E_C = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("East Central") == True]
EDR_7E_C.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 58   EDR  7E- East Central                       1                 1
# 59   EDR  7E- East Central                       1                 1
# 417  EDR  7E- East Central                       2                 2
# 418  EDR  7E- East Central                       2                 2
# 419  EDR  7E- East Central                       2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 58                 1.0                   0         19-50        35868
# 59                 1.0                   0           51+        36228
# 417                2.0                   0           51+        47412
# 418                1.5                   0           51+        47412
# 419                2.0                   0         19-50        46656
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 58         17.24           0   349          157      892        824    340
# 59         17.42           0   338          196      892        824    336
# 417        11.40           0   619          530      908        899    418
# 418        15.20           0   619          530      908        899    418
# 419        11.22           0   641          453      908        899    424
#
#      Taxes
# 58     427
# 59     433
# 417    577
# 418    577
# 419    563

# %%
#Combine data for each EDR into 1 data set - EDR 7W - Central
EDR_7W_C = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("7W") == True]
EDR_7W_C.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 60   EDR  7W- Central                            1                 1
# 61   EDR  7W- Central                            1                 1
# 424  EDR  7W- Central                            2                 2
# 425  EDR  7W- Central                            2                 1
# 426  EDR  7W- Central                            2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 60                 1.0                   0         19-50        33960
# 61                 1.0                   0           51+        34308
# 424                2.0                   0         19-50        44532
# 425                1.0                   1         19-50        55032
# 426                1.0                   0         19-50        43452
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 60         16.33           0   350          157      889        707    339
# 61         16.49           0   338          195      889        707    336
# 424        10.70           0   641          455      903        768    423
# 425        26.46         863   517          441     1115        712    447
# 426        20.89           0   641          455      903        768    423
#
#      Taxes
# 60     388
# 61     394
# 424    521
# 425    491
# 426    431

# %%
#Combine data for each EDR into 1 data set - EDR 8 - Southwest
EDR_8_SW = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("8") == True]
EDR_8_SW.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 62   EDR  8 - Southwest                          1                 1
# 63   EDR  8 - Southwest                          1                 1
# 431  EDR  8 - Southwest                          2                 2
# 432  EDR  8 - Southwest                          2                 2
# 433  EDR  8 - Southwest                          2                 1
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 62                 1.0                   0         19-50        27180
# 63                 1.0                   0           51+        27564
# 431                1.5                   0         19-50        38208
# 432                2.0                   0           51+        38964
# 433                1.0                   1         19-50        40896
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 62         13.07           0   359          152      585        627    258
# 63         13.25           0   347          191      585        627    255
# 431        12.25           0   657          496      595        678    343
# 432         9.37           0   635          573      595        678    337
# 433        19.66         457   530          482      756        631    352
#
#      Taxes
# 62     284
# 63     292
# 431    415
# 432    429
# 433    200

# %%
#Combine data for each EDR into 1 data set - EDR 9 _ South Central
EDR_9_Sc = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("South Central") == True]
EDR_9_Sc.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 64   EDR  9 - South Central                      1                 1
# 65   EDR  9 - South Central                      1                 1
# 438  EDR  9 - South Central                      2                 1
# 439  EDR  9 - South Central                      2                 2
# 440  EDR  9 - South Central                      2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 64                 1.0                   0           51+        29196
# 65                 1.0                   0         19-50        28824
# 438                1.0                   1         19-50        44172
# 439                1.0                   0           51+        39660
# 440                1.5                   0         19-50        39840
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 64         14.04           0   343          191      676        630    279
# 65         13.86           0   355          152      676        630    282
# 438        21.24         497   525          482      888        634    387
# 439        19.07           0   628          573      686        681    360
# 440        12.77           0   650          496      686        681    366
#
#      Taxes
# 64     314
# 65     307
# 438    268
# 439    377
# 440    441

# %%
#Combine data for each EDR into 1 data set - EDR 910 - Southesat
EDR_10_SE = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("Southeast") == True]
EDR_10_SE.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 66   EDR 10 - Southeast                          1                 1
# 67   EDR 10 - Southeast                          1                 1
# 445  EDR 10 - Southeast                          2                 2
# 446  EDR 10 - Southeast                          2                 1
# 447  EDR 10 - Southeast                          2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 66                 1.0                   0           51+        30072
# 67                 1.0                   0         19-50        29724
# 445                1.5                   0         19-50        40812
# 446                1.0                   1         19-50        48816
# 447                1.0                   0           51+        40608
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 66         14.46           0   342          191      685        676    281
# 67         14.29           0   354          152      685        676    285
# 445        13.08           0   649          496      696        732    368
# 446        23.47         729   524          482      895        680    388
# 447        19.52           0   627          573      696        732    362
#
#      Taxes
# 66     331
# 67     325
# 445    460
# 446    370
# 447    394

# %%
#Combine data for each EDR into 1 data set - EDR 11 - 7 County Twin Cities
EDR_11_TC = cost_of_living_EDR[cost_of_living_EDR["Area"].str.contains("7 County Twin Cities") == True]
EDR_11_TC.head()
# Out:
#                                  Area  Family Size  Number of Adults  \
# 68   EDR 11 - 7 County Twin Cities               1                 1
# 69   EDR 11 - 7 County Twin Cities               1                 1
# 452  EDR 11 - 7 County Twin Cities               2                 2
# 453  EDR 11 - 7 County Twin Cities               2                 2
# 454  EDR 11 - 7 County Twin Cities               2                 2
#
#      Number of Workers  Number of Children Age of Adults  Yearly Cost  \
# 68                 1.0                   0           51+        36864
# 69                 1.0                   0         19-50        36540
# 452                1.0                   0         19-50        45648
# 453                1.0                   0           51+        46416
# 454                2.0                   0           51+        47580
#
#      Hourly Wage  Child Care  Food  Health Care  Housing  Transport  Other  \
# 68         17.72           0   352          199     1066        640    388
# 69         17.57           0   364          161     1066        640    392
# 452        21.95           0   668          420     1086        693    480
# 453        22.32           0   646          497     1086        693    474
# 454        11.44           0   646          497     1086        693    474
#
#      Taxes
# 68     427
# 69     422
# 452    457
# 453    472
# 454    569

# %%
#Average Expenses for EDR 11, full average
EDR_11_TC_mean_expenses = EDR_11_TC["Yearly Cost"].mean()
EDR_11_TC_mean_expenses
# Out:
# 73917.5

# %% [markdown]
# Average Minnesota household size is a 3 member household. Calculated the averages for Yearly Cost (expenses), Hourly Wages, and Housing Cost for each EDR.

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_1_NW[EDR_1_NW["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_1_NW[EDR_1_NW["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_1_NW[EDR_1_NW["Family Size"]==3]["Housing"].mean()
aw = EDR_1_NW[EDR_1_NW["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_1_NW[EDR_1_NW["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_1_NW_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_1_NW_mean_expenses3.insert(0,"Area", EDR_1_NW["Area"][44])
EDR_1_NW_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  1 - Northwest                    48591.0      18.4975   881.75
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      38474.8            76949.6            126.293054
#
#    Income Expense Ratio (2FT)
# 0                   63.146527

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_2_hw[EDR_2_hw["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_2_hw[EDR_2_hw["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_2_hw[EDR_2_hw["Family Size"]==3]["Housing"].mean()
aw = EDR_2_hw[EDR_2_hw["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_2_hw[EDR_2_hw["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_2_hw_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_2_hw_mean_expenses3.insert(0,"Area", EDR_2_hw["Area"][46])
EDR_2_hw_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  2 - Headwaters                   51054.0       19.385    854.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      40320.8            80641.6            126.619512
#
#    Income Expense Ratio (2FT)
# 0                   63.309756

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_3_aw[EDR_3_aw["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_3_aw[EDR_3_aw["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_3_aw[EDR_3_aw["Family Size"]==3]["Housing"].mean()
aw = EDR_3_aw[EDR_3_aw["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_3_aw[EDR_3_aw["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_3_aw_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_3_aw_mean_expenses3.insert(0,"Area", EDR_3_aw["Area"][48])
EDR_3_aw_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  3 - Arrowhead                    54321.0      20.6625   940.75
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      42978.0            85956.0            126.392573
#
#    Income Expense Ratio (2FT)
# 0                   63.196286

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_4_WC[EDR_4_WC["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_4_WC[EDR_4_WC["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_4_WC[EDR_4_WC["Family Size"]==3]["Housing"].mean()
aw = EDR_4_WC[EDR_4_WC["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_4_WC[EDR_4_WC["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_4_WC_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_4_WC_mean_expenses3.insert(0,"Area", EDR_4_WC["Area"][50])
EDR_4_WC_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  4 - West Central                 50355.0       19.145   872.75
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      39821.6            79643.2            126.451474
#
#    Income Expense Ratio (2FT)
# 0                   63.225737

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_5_NC[EDR_5_NC["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_5_NC[EDR_5_NC["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_5_NC[EDR_5_NC["Family Size"]==3]["Housing"].mean()
aw = EDR_5_NC[EDR_5_NC["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_5_NC[EDR_5_NC["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_5_NC_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_5_NC_mean_expenses3.insert(0,"Area", EDR_5_NC["Area"][52])
EDR_5_NC_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  5 - North Central                51675.0       19.615    838.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      40799.2            81598.4            126.656895
#
#    Income Expense Ratio (2FT)
# 0                   63.328448

# %%
#Calculated Average Expenses, and put into dataframe
c= EDR_6E_SWC[EDR_6E_SWC["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_6E_SWC[EDR_6E_SWC["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_6E_SWC[EDR_6E_SWC["Family Size"]==3]["Housing"].mean()
aw = EDR_6E_SWC[EDR_6E_SWC["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_6E_SWC[EDR_6E_SWC["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_6E_SWC_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_6E_SWC_mean_expenses3.insert(0,"Area", EDR_6E_SWC["Area"][54])
EDR_6E_SWC_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  6E- Southwest Central            51675.0       19.305   844.75
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      40154.4            80308.8            128.690754
#
#    Income Expense Ratio (2FT)
# 0                   64.345377

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_6W_umnv[EDR_6W_umnv["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_6W_umnv[EDR_6W_umnv["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_6W_umnv[EDR_6W_umnv["Family Size"]==3]["Housing"].mean()
aw = EDR_6W_umnv[EDR_6W_umnv["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_6W_umnv[EDR_6W_umnv["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_6W_umnv_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_6W_umnv_mean_expenses3.insert(0,"Area", EDR_6W_umnv["Area"][56])
EDR_6W_umnv_mean_expenses3
# Out:
#                               Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  6W- Upper Minnesota Valley      48342.0        18.39    822.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      38251.2            76502.4            126.380349
#
#    Income Expense Ratio (2FT)
# 0                   63.190174

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_7E_C[EDR_7E_C["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_7E_C[EDR_7E_C["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_7E_C[EDR_7E_C["Family Size"]==3]["Housing"].mean()
aw = EDR_7E_C[EDR_7E_C["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_7E_C[EDR_7E_C["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_7E_C_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_7E_C_mean_expenses3.insert(0,"Area", EDR_7E_C["Area"][58])
EDR_7E_C_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  7E- East Central                 66591.0      25.3875   1260.0
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      52806.0           105612.0            126.104988
#
#    Income Expense Ratio (2FT)
# 0                   63.052494

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_7W_C[EDR_7W_C["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_7W_C[EDR_7W_C["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_7W_C[EDR_7W_C["Family Size"]==3]["Housing"].mean()
aw = EDR_7W_C[EDR_7W_C["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 =  EDR_7W_C[ EDR_7W_C["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_7W_C_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_7W_C_mean_expenses3.insert(0,"Area", EDR_7W_C["Area"][60])
EDR_7W_C_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  7W- Central                      63357.0       24.245   1228.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      50429.6           100859.2            125.634548
#
#    Income Expense Ratio (2FT)
# 0                   62.817274

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_8_SW[EDR_8_SW["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_8_SW[EDR_8_SW["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_8_SW[EDR_8_SW["Family Size"]==3]["Housing"].mean()
aw = EDR_8_SW[EDR_8_SW["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_8_SW[EDR_8_SW["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_8_SW_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_8_SW_mean_expenses3.insert(0,"Area", EDR_8_SW["Area"][62])
EDR_8_SW_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  8 - Southwest                    47772.0      18.1725   821.25
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      37798.8            75597.6            126.384965
#
#    Income Expense Ratio (2FT)
# 0                   63.192482

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_9_Sc[EDR_9_Sc["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_9_Sc[EDR_9_Sc["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_9_Sc[EDR_9_Sc["Family Size"]==3]["Housing"].mean()
aw = EDR_9_Sc[EDR_9_Sc["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_9_Sc[EDR_9_Sc["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_9_Sc_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_9_Sc_mean_expenses3.insert(0,"Area", EDR_9_Sc["Area"][64])
EDR_9_Sc_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  9 - South Central                51150.0       19.475    971.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      40508.0            81016.0            126.271354
#
#    Income Expense Ratio (2FT)
# 0                   63.135677

# %%
#Calculated Average Expenses, and put into dataframe
yc= EDR_10_SE[EDR_10_SE["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_10_SE[EDR_10_SE["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_10_SE[EDR_10_SE["Family Size"]==3]["Housing"].mean()
aw = EDR_10_SE[EDR_10_SE["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_10_SE[EDR_10_SE["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_10_SE_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_10_SE_mean_expenses3.insert(0,"Area", EDR_10_SE["Area"][66])
EDR_10_SE_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR 10 - Southeast                    55437.0       21.125    983.0
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      43940.0            87880.0            126.165225
#
#    Income Expense Ratio (2FT)
# 0                   63.082613

# %%
#Calculated Average Expenses, and put into dataframe
yc = EDR_11_TC[EDR_11_TC["Family Size"]==3]["Yearly Cost"].mean()
hw = EDR_11_TC[EDR_11_TC["Family Size"]==3]["Hourly Wage"].mean()
h = EDR_11_TC[EDR_11_TC["Family Size"]==3]["Housing"].mean()
aw = EDR_11_TC[EDR_11_TC["Family Size"]==3]["Hourly Wage"].mean() *2080
aw2 = EDR_11_TC[EDR_11_TC["Family Size"]==3]["Hourly Wage"].mean() *2080 * 2
ier1 = yc / aw * 100
ier2 = yc / aw2 * 100
EDR_11_TC_mean_expenses3 = pd.DataFrame({"Yearly Cost": yc,
                                        "Hourly Wage": hw, 
                                        "Housing": h, 
                                        "Annual Wage": aw,
                                        "Annual Wage (2FT)": aw2,
                                        "Income Expense Ratio": ier1,
                                        "Income Expense Ratio (2FT)": ier2}, index=[0])
EDR_11_TC_mean_expenses3.insert(0,"Area", EDR_11_TC["Area"][68])
EDR_11_TC_mean_expenses3
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR 11 - 7 County Twin Cities         76563.0        29.27   1484.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      60881.6           121763.2            125.757207
#
#    Income Expense Ratio (2FT)
# 0                   62.878604

# %%
#Created new data frame with all of the household size of 3 average information. 
frames = [EDR_1_NW_mean_expenses3, EDR_2_hw_mean_expenses3, EDR_3_aw_mean_expenses3, EDR_4_WC_mean_expenses3, EDR_5_NC_mean_expenses3, EDR_6E_SWC_mean_expenses3, EDR_6W_umnv_mean_expenses3, EDR_7E_C_mean_expenses3, EDR_7W_C_mean_expenses3, EDR_8_SW_mean_expenses3, EDR_9_Sc_mean_expenses3, EDR_10_SE_mean_expenses3, EDR_11_TC_mean_expenses3]
EDR_yearly_expenses_3 = pd.concat(frames,ignore_index=True)
EDR_yearly_expenses_3
# Out:
#                                 Area  Yearly Cost  Hourly Wage  Housing  \
# 0   EDR  1 - Northwest                    48591.0      18.4975   881.75
# 1   EDR  2 - Headwaters                   51054.0      19.3850   854.50
# 2   EDR  3 - Arrowhead                    54321.0      20.6625   940.75
# 3   EDR  4 - West Central                 50355.0      19.1450   872.75
# 4   EDR  5 - North Central                51675.0      19.6150   838.50
# 5   EDR  6E- Southwest Central            51675.0      19.3050   844.75
# 6    EDR  6W- Upper Minnesota Valley      48342.0      18.3900   822.50
# 7   EDR  7E- East Central                 66591.0      25.3875  1260.00
# 8   EDR  7W- Central                      63357.0      24.2450  1228.50
# 9   EDR  8 - Southwest                    47772.0      18.1725   821.25
# 10  EDR  9 - South Central                51150.0      19.4750   971.50
# 11  EDR 10 - Southeast                    55437.0      21.1250   983.00
# 12  EDR 11 - 7 County Twin Cities         76563.0      29.2700  1484.50
#
#     Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0       38474.8            76949.6            126.293054
# 1       40320.8            80641.6            126.619512
# 2       42978.0            85956.0            126.392573
# 3       39821.6            79643.2            126.451474
# 4       40799.2            81598.4            126.656895
# 5       40154.4            80308.8            128.690754
# 6       38251.2            76502.4            126.380349
# 7       52806.0           105612.0            126.104988
# 8       50429.6           100859.2            125.634548
# 9       37798.8            75597.6            126.384965
# 10      40508.0            81016.0            126.271354
# 11      43940.0            87880.0            126.165225
# 12      60881.6           121763.2            125.757207
#
#     Income Expense Ratio (2FT)
# 0                    63.146527
# 1                    63.309756
# 2                    63.196286
# 3                    63.225737
# 4                    63.328448
# 5                    64.345377
# 6                    63.190174
# 7                    63.052494
# 8                    62.817274
# 9                    63.192482
# 10                   63.135677
# 11                   63.082613
# 12                   62.878604

# %%
# Yearly Cost Comparisson and Annual Wage for EDRs
cost = EDR_yearly_expenses_3.filter(items=['Area', 'Yearly Cost','Annual Wage', 'Annual Wage (2FT)'])
cost

cost_comp = cost.plot(kind='bar')
cost_comp
cost_comp.set_ylabel("Dollars ($)")
cost_comp.set_title("Annual Wage verses Yearly Expenses, 3 person households")
plt.xlabel(("Minnesota Economic Development Regions"), size = 12)
plt.figure(figsize=(12,8))
plt.savefig("output_data/wage_v_expense.png")
plt.show()

# %%
# Create Bar graph to show Yearly Cost over all EDR 
x_axis = np.arange(len(EDR_yearly_expenses_3))
tick_locations = [value+0.4 for value in x_axis] 
plt.figure(figsize = (12,8))
plt.bar(x_axis, EDR_yearly_expenses_3["Yearly Cost"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, EDR_yearly_expenses_3["Area"], rotation="vertical")
plt.title(("Average Yearly Expenses for Minnesota EDR's for Households of 3"), size = 14)
plt.ylabel(("Expenses ($)"), size = 12)
plt.xlabel(("Minnesota Economic Development Regions"), size = 12)
plt.savefig("output_data/yearly_expense.png")
plt.show()

# %%
# Create Bar graph to show Average Housing Cost over all EDR 
x_axis = np.arange(len(EDR_yearly_expenses_3))
tick_locations = [value+0.4 for value in x_axis] 
plt.figure(figsize = (12,8))
plt.bar(x_axis, EDR_yearly_expenses_3["Housing"], color='g', alpha=0.5, align="edge")
plt.xticks(tick_locations, EDR_yearly_expenses_3["Area"], rotation="vertical")
plt.title(("Average Monthly Housing Expenses for Minnesota EDR's for Households of 3"), size = 14)
plt.ylabel(("Expenses ($)"), size = 12)
plt.xlabel(("Minnesota Economic Development Regions"), size = 12),
plt.savefig("output_data/monthly_housing.png")
plt.show()

# %%
# Create Bar graph to show Average Hourly Wage for all EDRs
x_axis = np.arange(len(EDR_yearly_expenses_3))
tick_locations = [value+0.4 for value in x_axis] 
plt.figure(figsize = (12,8))
plt.bar(x_axis, EDR_yearly_expenses_3["Hourly Wage"], color='b', alpha=0.5, align="edge")
plt.xticks(tick_locations, EDR_yearly_expenses_3["Area"], rotation="vertical")
plt.title(("Average Hourly Wage for Minnesota EDR's for Households of 3"), size = 14)
plt.ylabel(("Hourly Rate ($)"), size = 12)
plt.xlabel(("Minnesota Economic Development Regions"), size = 12)
plt.savefig("output_data/hourly_wage.png")
plt.show()

# %% [markdown]
# When looking at these graphs, they all follow a very similar pattern on the graph. The Twin Cities has the highest yearly expenses $76,560 compared to $47,772 for the Southwest EDR. For the average monthly housing expenses, the Southwest had the lowest cost, compared to the Twin Cities with the highest cost. Not surprizing the Twin Cities employees had the highest hourly wage rate at $29.27; with the Southwest Region having an hourly rate of $18.17.  East Central and Central EDR Regions were the closest EDR to matching the Twin Cities.

# %%
#Look at the top 3 EDRs with highest wages, and/or largest expenses.
frames = [ EDR_7E_C_mean_expenses3, EDR_7W_C_mean_expenses3, EDR_11_TC_mean_expenses3]
EDR_yearly_expenses_top = pd.concat(frames,ignore_index=True)
EDR_yearly_expenses_top
# Out:
#                                Area  Yearly Cost  Hourly Wage  Housing  \
# 0  EDR  7E- East Central                 66591.0      25.3875   1260.0
# 1  EDR  7W- Central                      63357.0      24.2450   1228.5
# 2  EDR 11 - 7 County Twin Cities         76563.0      29.2700   1484.5
#
#    Annual Wage  Annual Wage (2FT)  Income Expense Ratio  \
# 0      52806.0           105612.0            126.104988
# 1      50429.6           100859.2            125.634548
# 2      60881.6           121763.2            125.757207
#
#    Income Expense Ratio (2FT)
# 0                   63.052494
# 1                   62.817274
# 2                   62.878604

# %% [markdown]
# Income Expense Ratio = Expenses / Annual Wage

# %%
# Show the income expense rations
x_axis = np.arange(len(EDR_yearly_expenses_3))
tick_locations = [value+0.4 for value in x_axis] 
plt.figure(figsize = (8,6))
plt.bar(x_axis, EDR_yearly_expenses_3["Income Expense Ratio"], color='purple', alpha=0.5, align="edge")
plt.xticks(tick_locations, EDR_yearly_expenses_3["Area"], rotation="vertical")
plt.title(("Income Expense Ratio (1 Full Time Worker) for Minnesota EDR's for Households of 3"), size = 14)
plt.ylabel(("Ratio"), size = 12)
plt.xlabel(("Minnesota Economic Development Regions"), size = 12)
plt.ylim(120,130)
plt.savefig("output_data/inc_exp_ratio1.png")
plt.show()

# %%
# Show the income expense rations
x_axis = np.arange(len(EDR_yearly_expenses_3))
tick_locations = [value+0.4 for value in x_axis] 
plt.figure(figsize = (8,6))
plt.bar(x_axis, EDR_yearly_expenses_3["Income Expense Ratio (2FT)"], color='pink', alpha=0.5, align="edge")
plt.xticks(tick_locations, EDR_yearly_expenses_3["Area"], rotation="vertical")
plt.title(("Income Expense Ratio (2 Full Time Workers) for Minnesota EDR's for Households of 3"), size = 14)
plt.ylabel(("Ratio"), size = 12)
plt.ylim(60,65)
plt.xlabel(("Minnesota Economic Development Regions"), size = 12)
plt.savefig("output_data/inc_exp_ratio1.png")
plt.show()

# %% [markdown]
# EDR 7W - Central has the best income to expense ratio (the smallest number), followed closely by the EDR 11 - Twin Cities.  EDR 6E Southwest Central families have the smallest gap between their annual wages and the expenses that they have.
# For those in a dual income household they will be able to potential save money throughout the year; where as on average a single household worker spends more than their annual salary.
